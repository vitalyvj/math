# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt
from scipy.optimize import fsolve

# %%
# задание 1

x = np.linspace(-10, 10, 1001)

k1 = 1
a1 = 2
b1 = 3

k2 = 3
a2 = 2
b2 = 1

k3 = 4
a3 = 5
b3 = -2

plt.plot(x, k1 * np.cos(x - a1) + b1)
plt.plot(x, k2 * np.cos(x - a2) + b2)
plt.plot(x, k3 * np.cos(x - a3) + b3)

plt.xlabel('x')
plt.ylabel('y (x) = k∙cos(x – a) + b')
plt.grid()

# %%
# задание 3

R = 10
alpha = np.pi / 4

x1 = R * np.cos(alpha)
y1 = R * np.sin(alpha)

print('R =', R)
print('alpha =', alpha)
print('x1 =', x1, 'y1 =', y1)


x = np.linspace(0, 2 * np.pi, 101)
y = [R for i in range(101)]
plt.polar(x, y)

x = np.linspace(0, 8, 101)
y = 2 * x - 3
plt.polar(x, y)

plt.show()
# Out:
# R = 10
# alpha = 0.7853981633974483
# x1 = 7.0710678118654755 y1 = 7.071067811865475

# %%
# система уравнений

x = np.linspace(-5, 5, 101)


def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x * (1 - y) - 1)

x1, y1 = fsolve(equations, (-2, 2))
print (x1, y1)

x2, y2 = fsolve(equations, (3, 6))
print (x2, y2)


plt.plot(x, 1 - ((1 - np.exp(x)) / x))
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1, 10) 
plt.grid()
# Out:
# -1.5818353528958982 1.5022030836712916
# 2.618145573086073 5.8546862418707315
# <ipython-input-4-29780dd58840>:17: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x, 1 - ((1 - np.exp(x)) / x))

# %%
# система неравенств

x = np.linspace(-5, 5, 101)


def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x * (1 - y) - 1)

x1, y1 = fsolve(equations, (-2, 2))
print (x1, y1)

x2, y2 = fsolve(equations, (3, 6))
print (x2, y2)

x = np.linspace(-5, x1, 101)
plt.plot(x, x**2 - 1)

x = np.linspace(x2, 5, 101)
plt.plot(x, x**2 - 1)

plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1, 10) 
plt.grid()
# Out:
# -1.5818353528958982 1.5022030836712916
# 2.618145573086073 5.8546862418707315
